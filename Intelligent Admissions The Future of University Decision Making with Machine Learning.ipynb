# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("Admission_Predict.csv")

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 395         1             0.82
# 396         1             0.84
# 397         1             0.91
# 398         0             0.67
# 399         1             0.95
#
# [400 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
data.isnull()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0         False      False        False              False  False  False
# 1         False      False        False              False  False  False
# 2         False      False        False              False  False  False
# 3         False      False        False              False  False  False
# 4         False      False        False              False  False  False
# ..          ...        ...          ...                ...    ...    ...
# 395       False      False        False              False  False  False
# 396       False      False        False              False  False  False
# 397       False      False        False              False  False  False
# 398       False      False        False              False  False  False
# 399       False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False            False
# 1    False     False            False
# 2    False     False            False
# 3    False     False            False
# 4    False     False            False
# ..     ...       ...              ...
# 395  False     False            False
# 396  False     False            False
# 397  False     False            False
# 398  False     False            False
# 399  False     False            False
#
# [400 rows x 9 columns]

# %%
data.sum()
# Out:
# Serial No.            80200.00
# GRE Score            126723.00
# TOEFL Score           42964.00
# University Rating      1235.00
# SOP                    1360.00
# LOR                    1381.00
# CGPA                   3439.57
# Research                219.00
# Chance of Admit         289.74
# dtype: float64

# %%
data.isnull().any()
# Out:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
data=data.rename(columns ={'Chance of Admit ':'Chance of Admit'})

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000       400.000000
# mean     3.452500    8.598925    0.547500         0.724350
# std      0.898478    0.596317    0.498362         0.142609
# min      1.000000    6.800000    0.000000         0.340000
# 25%      3.000000    8.170000    0.000000         0.640000
# 50%      3.500000    8.610000    1.000000         0.730000
# 75%      4.000000    9.062500    1.000000         0.830000
# max      5.000000    9.920000    1.000000         0.970000

# %%
sns.distplot(data['GRE Score'])
# Out:
# C:\Users\Dhanush\AppData\Local\Temp\ipykernel_1192\162670230.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['GRE Score'])
# <Axes: xlabel='GRE Score', ylabel='Density'>

# %%
sns.pairplot(data=data,hue='Research',markers=["^", "v"],palette='inferno')

# %%
sns.scatterplot(x='University Rating',y='CGPA',data=data,color='Red', s=100)
# Out:
# <Axes: xlabel='University Rating', ylabel='CGPA'>

# %%
category = ['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research','Chance of Admit']
color = ['yellowgreen','gold','lightskyblue','pink','red','purple','orange','gray']
start = True
for i in np.arange(4):
    fig = plt.figure(figsize=(14,8))
    plt.subplot2grid((4,2),(i,0))
    data[category[2*i]].hist(color=color[2*i],bins=10)
    plt.title(category[2*i])
    plt.subplot2grid((4,2),(i,1))
    data[category[2*i+1]].hist(color=color[2*i+1],bins=10)
    plt.title(category[2*i+1])
    
plt.subplots_adjust(hspace = 0.7, wspace = 0.2)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[0.        , 0.94      , 0.92857143, ..., 0.875     , 0.875     ,
#         0.91346154],
#        [0.00250627, 0.68      , 0.53571429, ..., 0.75      , 0.875     ,
#         0.66346154],
#        [0.00501253, 0.52      , 0.42857143, ..., 0.5       , 0.625     ,
#         0.38461538],
#        ...,
#        [0.99498747, 0.8       , 0.85714286, ..., 1.        , 0.875     ,
#         0.84935897],
#        [0.99749373, 0.44      , 0.39285714, ..., 0.625     , 0.75      ,
#         0.63461538],
#        [1.        , 0.86      , 0.89285714, ..., 1.        , 0.75      ,
#         0.91666667]])

# %%
x=data.iloc[:,0:7].values
x
# Out:
# array([[  1.  , 337.  , 118.  , ...,   4.5 ,   4.5 ,   9.65],
#        [  2.  , 324.  , 107.  , ...,   4.  ,   4.5 ,   8.87],
#        [  3.  , 316.  , 104.  , ...,   3.  ,   3.5 ,   8.  ],
#        ...,
#        [398.  , 330.  , 116.  , ...,   5.  ,   4.5 ,   9.45],
#        [399.  , 312.  , 103.  , ...,   3.5 ,   4.  ,   8.78],
#        [400.  , 333.  , 117.  , ...,   5.  ,   4.  ,   9.66]])

# %%
y=data.iloc[:,8:].values
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
#        [0.36],
#        [0.42],
#        [0.48],
#        [0.47],
#        [0.54],
#        [0.56],
#        [0.52],
#        [0.55],
#        [0.61],
#        [0.57],
#        [0.68],
#        [0.78],
#        [0.94],
#        [0.96],
#        [0.93],
#        [0.84],
#        [0.74],
#        [0.72],
#        [0.74],
#        [0.64],
#        [0.44],
#        [0.46],
#        [0.5 ],
#        [0.96],
#        [0.92],
#        [0.92],
#        [0.94],
#        [0.76],
#        [0.72],
#        [0.66],
#        [0.64],
#        [0.74],
#        [0.64],
#        [0.38],
#        [0.34],
#        [0.44],
#        [0.36],
#        [0.42],
#        [0.48],
#        [0.86],
#        [0.9 ],
#        [0.79],
#        [0.71],
#        [0.64],
#        [0.62],
#        [0.57],
#        [0.74],
#        [0.69],
#        [0.87],
#        [0.91],
#        [0.93],
#        [0.68],
#        [0.61],
#        [0.69],
#        [0.62],
#        [0.72],
#        [0.59],
#        [0.66],
#        [0.56],
#        [0.45],
#        [0.47],
#        [0.71],
#        [0.94],
#        [0.94],
#        [0.57],
#        [0.61],
#        [0.57],
#        [0.64],
#        [0.85],
#        [0.78],
#        [0.84],
#        [0.92],
#        [0.96],
#        [0.77],
#        [0.71],
#        [0.79],
#        [0.89],
#        [0.82],
#        [0.76],
#        [0.71],
#        [0.8 ],
#        [0.78],
#        [0.84],
#        [0.9 ],
#        [0.92],
#        [0.97],
#        [0.8 ],
#        [0.81],
#        [0.75],
#        [0.83],
#        [0.96],
#        [0.79],
#        [0.93],
#        [0.94],
#        [0.86],
#        [0.79],
#        [0.8 ],
#        [0.77],
#        [0.7 ],
#        [0.65],
#        [0.61],
#        [0.52],
#        [0.57],
#        [0.53],
#        [0.67],
#        [0.68],
#        [0.81],
#        [0.78],
#        [0.65],
#        [0.64],
#        [0.64],
#        [0.65],
#        [0.68],
#        [0.89],
#        [0.86],
#        [0.89],
#        [0.87],
#        [0.85],
#        [0.9 ],
#        [0.82],
#        [0.72],
#        [0.73],
#        [0.71],
#        [0.71],
#        [0.68],
#        [0.75],
#        [0.72],
#        [0.89],
#        [0.84],
#        [0.93],
#        [0.93],
#        [0.88],
#        [0.9 ],
#        [0.87],
#        [0.86],
#        [0.94],
#        [0.77],
#        [0.78],
#        [0.73],
#        [0.73],
#        [0.7 ],
#        [0.72],
#        [0.73],
#        [0.72],
#        [0.97],
#        [0.97],
#        [0.69],
#        [0.57],
#        [0.63],
#        [0.66],
#        [0.64],
#        [0.68],
#        [0.79],
#        [0.82],
#        [0.95],
#        [0.96],
#        [0.94],
#        [0.93],
#        [0.91],
#        [0.85],
#        [0.84],
#        [0.74],
#        [0.76],
#        [0.75],
#        [0.76],
#        [0.71],
#        [0.67],
#        [0.61],
#        [0.63],
#        [0.64],
#        [0.71],
#        [0.82],
#        [0.73],
#        [0.74],
#        [0.69],
#        [0.64],
#        [0.91],
#        [0.88],
#        [0.85],
#        [0.86],
#        [0.7 ],
#        [0.59],
#        [0.6 ],
#        [0.65],
#        [0.7 ],
#        [0.76],
#        [0.63],
#        [0.81],
#        [0.72],
#        [0.71],
#        [0.8 ],
#        [0.77],
#        [0.74],
#        [0.7 ],
#        [0.71],
#        [0.93],
#        [0.85],
#        [0.79],
#        [0.76],
#        [0.78],
#        [0.77],
#        [0.9 ],
#        [0.87],
#        [0.71],
#        [0.7 ],
#        [0.7 ],
#        [0.75],
#        [0.71],
#        [0.72],
#        [0.73],
#        [0.83],
#        [0.77],
#        [0.72],
#        [0.54],
#        [0.49],
#        [0.52],
#        [0.58],
#        [0.78],
#        [0.89],
#        [0.7 ],
#        [0.66],
#        [0.67],
#        [0.68],
#        [0.8 ],
#        [0.81],
#        [0.8 ],
#        [0.94],
#        [0.93],
#        [0.92],
#        [0.89],
#        [0.82],
#        [0.79],
#        [0.58],
#        [0.56],
#        [0.56],
#        [0.64],
#        [0.61],
#        [0.68],
#        [0.76],
#        [0.86],
#        [0.9 ],
#        [0.71],
#        [0.62],
#        [0.66],
#        [0.65],
#        [0.73],
#        [0.62],
#        [0.74],
#        [0.79],
#        [0.8 ],
#        [0.69],
#        [0.7 ],
#        [0.76],
#        [0.84],
#        [0.78],
#        [0.67],
#        [0.66],
#        [0.65],
#        [0.54],
#        [0.58],
#        [0.79],
#        [0.8 ],
#        [0.75],
#        [0.73],
#        [0.72],
#        [0.62],
#        [0.67],
#        [0.81],
#        [0.63],
#        [0.69],
#        [0.8 ],
#        [0.43],
#        [0.8 ],
#        [0.73],
#        [0.75],
#        [0.71],
#        [0.73],
#        [0.83],
#        [0.72],
#        [0.94],
#        [0.81],
#        [0.81],
#        [0.75],
#        [0.79],
#        [0.58],
#        [0.59],
#        [0.47],
#        [0.49],
#        [0.47],
#        [0.42],
#        [0.57],
#        [0.62],
#        [0.74],
#        [0.73],
#        [0.64],
#        [0.63],
#        [0.59],
#        [0.73],
#        [0.79],
#        [0.68],
#        [0.7 ],
#        [0.81],
#        [0.85],
#        [0.93],
#        [0.91],
#        [0.69],
#        [0.77],
#        [0.86],
#        [0.74],
#        [0.57],
#        [0.51],
#        [0.67],
#        [0.72],
#        [0.89],
#        [0.95],
#        [0.79],
#        [0.39],
#        [0.38],
#        [0.34],
#        [0.47],
#        [0.56],
#        [0.71],
#        [0.78],
#        [0.73],
#        [0.82],
#        [0.62],
#        [0.96],
#        [0.96],
#        [0.46],
#        [0.53],
#        [0.49],
#        [0.76],
#        [0.64],
#        [0.71],
#        [0.84],
#        [0.77],
#        [0.89],
#        [0.82],
#        [0.84],
#        [0.91],
#        [0.67],
#        [0.95]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30,random_state=101)

# %%
y_train=(y_train>0.5)
y_train
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
y_test=(y_test>0.5)

# %%
from sklearn.linear_model import LogisticRegression
cls=LogisticRegression(random_state =0)


lr=cls.fit(x_train, y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# C:\Users\Dhanush\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model=keras.Sequential()
model.add(Dense(7,activation ='relu',input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(1,activation='linear'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 7)                 56
#
#  dense_7 (Dense)             (None, 7)                 56
#
#  dense_8 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 120
# Trainable params: 120
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam',metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 20,epochs = 100)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 17s 15ms/step - loss: 13.3013 - accuracy: 0.0821
# Epoch 2/100
# 14/14 [==============================] - 0s 13ms/step - loss: 12.7116 - accuracy: 0.0821
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 11.7216 - accuracy: 0.0821
# Epoch 4/100
# 14/14 [==============================] - 0s 6ms/step - loss: 10.2361 - accuracy: 0.0821
# Epoch 5/100
# 14/14 [==============================] - 0s 6ms/step - loss: 7.9074 - accuracy: 0.0821
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 4.1533 - accuracy: 0.0821
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.5488 - accuracy: 0.0821
# Epoch 8/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1840 - accuracy: 0.0821
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0273 - accuracy: 0.0857
# Epoch 10/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9028 - accuracy: 0.1143
# Epoch 11/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7914 - accuracy: 0.3143
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.5429
# Epoch 13/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6041 - accuracy: 0.7500
# Epoch 14/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5242 - accuracy: 0.8357
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4495 - accuracy: 0.8786
# Epoch 16/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3806 - accuracy: 0.9036
# Epoch 17/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3196 - accuracy: 0.8929
# Epoch 18/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2729 - accuracy: 0.9036
# Epoch 19/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2438 - accuracy: 0.9143
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2283 - accuracy: 0.9107
# Epoch 21/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2217 - accuracy: 0.9179
# Epoch 22/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2178 - accuracy: 0.9179
# Epoch 23/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2163 - accuracy: 0.9179
# Epoch 24/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2105 - accuracy: 0.9143
# Epoch 25/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2069 - accuracy: 0.9179
# Epoch 26/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2044 - accuracy: 0.9179
# Epoch 27/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2018 - accuracy: 0.9143
# Epoch 28/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1993 - accuracy: 0.9143
# Epoch 29/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1973 - accuracy: 0.9143
# Epoch 30/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1951 - accuracy: 0.9143
# Epoch 31/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1932 - accuracy: 0.9143
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1917 - accuracy: 0.9143
# Epoch 33/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1900 - accuracy: 0.9143
# Epoch 34/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1902 - accuracy: 0.9143
# Epoch 35/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1875 - accuracy: 0.9143
# Epoch 36/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1867 - accuracy: 0.9143
# Epoch 37/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1851 - accuracy: 0.9143
# Epoch 38/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1842 - accuracy: 0.9143
# Epoch 39/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1835 - accuracy: 0.9143
# Epoch 40/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1828 - accuracy: 0.9143
# Epoch 41/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1819 - accuracy: 0.9143
# Epoch 42/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1813 - accuracy: 0.9179
# Epoch 43/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1806 - accuracy: 0.9179
# Epoch 44/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1802 - accuracy: 0.9179
# Epoch 45/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1798 - accuracy: 0.9179
# Epoch 46/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1793 - accuracy: 0.9179
# Epoch 47/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1789 - accuracy: 0.9179
# Epoch 48/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1781 - accuracy: 0.9179
# Epoch 49/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1780 - accuracy: 0.9179
# Epoch 50/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1773 - accuracy: 0.9179
# Epoch 51/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1770 - accuracy: 0.9179
# Epoch 52/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1768 - accuracy: 0.9179
# Epoch 53/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1763 - accuracy: 0.9179
# Epoch 54/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1758 - accuracy: 0.9179
# Epoch 55/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9179
# Epoch 56/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1758 - accuracy: 0.9179
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1749 - accuracy: 0.9214
# Epoch 58/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1746 - accuracy: 0.9214
# Epoch 59/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1741 - accuracy: 0.9214
# Epoch 60/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1737 - accuracy: 0.9214
# Epoch 61/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1738 - accuracy: 0.9214
# Epoch 62/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1731 - accuracy: 0.9214
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1733 - accuracy: 0.9214
# Epoch 64/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1728 - accuracy: 0.9214
# Epoch 65/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1722 - accuracy: 0.9214
# Epoch 66/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1718 - accuracy: 0.9214
# Epoch 67/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 0.9214
# Epoch 68/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1712 - accuracy: 0.9214
# Epoch 69/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1707 - accuracy: 0.9214
# Epoch 70/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1702 - accuracy: 0.9214
# Epoch 71/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1700 - accuracy: 0.9214
# Epoch 72/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1697 - accuracy: 0.9214
# Epoch 73/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1692 - accuracy: 0.9214
# Epoch 74/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1688 - accuracy: 0.9214
# Epoch 75/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1683 - accuracy: 0.9214
# Epoch 76/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1678 - accuracy: 0.9250
# Epoch 77/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1677 - accuracy: 0.9250
# Epoch 78/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1672 - accuracy: 0.9250
# Epoch 79/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1671 - accuracy: 0.9250
# Epoch 80/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1664 - accuracy: 0.9250
# Epoch 81/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1663 - accuracy: 0.9250
# Epoch 82/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9250
# Epoch 83/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1655 - accuracy: 0.9250
# Epoch 84/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1651 - accuracy: 0.9250
# Epoch 85/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1655 - accuracy: 0.9250
# Epoch 86/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1652 - accuracy: 0.9250
# Epoch 87/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1639 - accuracy: 0.9250
# Epoch 88/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1635 - accuracy: 0.9286
# Epoch 89/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.9286
# Epoch 90/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1617 - accuracy: 0.9321
# Epoch 91/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1595 - accuracy: 0.9321
# Epoch 92/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1587 - accuracy: 0.9321
# Epoch 93/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1569 - accuracy: 0.9357
# Epoch 94/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1563 - accuracy: 0.9357
# Epoch 95/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1560 - accuracy: 0.9357
# Epoch 96/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1550 - accuracy: 0.9357
# Epoch 97/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1545 - accuracy: 0.9357
# Epoch 98/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1544 - accuracy: 0.9357
# Epoch 99/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1537 - accuracy: 0.9357
# Epoch 100/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1526 - accuracy: 0.9357

# %%
from sklearn.metrics import accuracy_score

train_predictions = model.predict(x_train)

print(train_predictions)
# Out:
# 9/9 [==============================] - 0s 5ms/step
# [[1.2595245 ]
#  [1.2957116 ]
#  [1.031512  ]
#  [1.1917521 ]
#  [0.8295551 ]
#  [1.0247191 ]
#  [1.4012556 ]
#  [1.1528132 ]
#  [1.0155361 ]
#  [1.0038639 ]
#  [1.3281187 ]
#  [1.0720766 ]
#  [1.4713457 ]
#  [1.0509712 ]
#  [1.0609046 ]
#  [0.57544094]
#  [0.53195035]
#  [0.7558911 ]
#  [1.0414121 ]
#  [0.8626348 ]
#  [0.80504745]
#  [1.1655624 ]
#  [0.9801243 ]
#  [0.88449657]
#  [1.1239055 ]
#  [1.0670815 ]
#  [1.2558293 ]
#  [1.2302444 ]
#  [0.8433883 ]
#  [1.1028247 ]
#  [1.0977396 ]
#  [0.58442426]
#  [1.2070017 ]
#  [0.7241516 ]
#  [1.0077888 ]
#  [1.1353831 ]
#  [1.4780153 ]
#  [0.9633788 ]
#  [1.3853385 ]
#  [0.55820084]
#  [0.94045687]
#  [1.089231  ]
#  [1.3571625 ]
#  [1.063949  ]
#  [0.8275524 ]
#  [0.84808034]
#  [0.84872586]
#  [1.16507   ]
#  [0.9517623 ]
#  [0.9891361 ]
#  [1.2168373 ]
#  [0.99299735]
#  [0.5154629 ]
#  [1.12392   ]
#  [1.133313  ]
#  [1.2170615 ]
#  [0.39030957]
#  [0.826103  ]
#  [1.2304598 ]
#  [1.1313524 ]
#  [1.2380173 ]
#  [1.3689617 ]
#  [1.0465689 ]
#  [0.8680334 ]
#  [0.8861203 ]
#  [0.99553204]
#  [1.2362609 ]
#  [0.6187966 ]
#  [1.0918294 ]
#  [0.6974596 ]
#  [1.1446457 ]
#  [0.82872057]
#  [1.0288798 ]
#  [1.0045763 ]
#  [1.1413128 ]
#  [1.1474462 ]
#  [0.6595391 ]
#  [1.109152  ]
#  [1.0387616 ]
#  [1.1884273 ]
#  [1.0515044 ]
#  [1.185303  ]
#  [0.696669  ]
#  [0.8593281 ]
#  [1.1968632 ]
#  [1.201615  ]
#  [0.9833231 ]
#  [1.3268905 ]
#  [1.0089258 ]
#  [1.11658   ]
#  [1.1063378 ]
#  [1.1713159 ]
#  [1.1259494 ]
#  [1.2977055 ]
#  [1.2290405 ]
#  [0.8964251 ]
#  [0.60606   ]
#  [0.6829238 ]
#  [1.1259689 ]
#  [0.8996433 ]
#  [1.1025213 ]
#  [0.98435295]
#  [0.94845366]
#  [1.3035927 ]
#  [0.8909422 ]
#  [1.1137875 ]
#  [1.0037493 ]
#  [0.83936596]
#  [0.93095815]
#  [0.774094  ]
#  [1.476963  ]
#  [1.2891037 ]
#  [0.96101934]
#  [0.9638179 ]
#  [1.2249544 ]
#  [0.94543076]
#  [1.2945724 ]
#  [1.2619045 ]
#  [0.85392463]
#  [1.1413989 ]
#  [0.96727246]
#  [0.62285686]
#  [0.4106585 ]
#  [1.0645362 ]
#  [1.5411997 ]
#  [0.7341889 ]
#  [0.7517446 ]
#  [0.8580003 ]
#  [1.2115211 ]
#  [1.1603948 ]
#  [1.331883  ]
#  [0.99496067]
#  [0.9853141 ]
#  [0.9912859 ]
#  [1.0449908 ]
#  [1.0092643 ]
#  [1.0478584 ]
#  [1.3247714 ]
#  [1.2449944 ]
#  [1.0764365 ]
#  [0.65116346]
#  [0.80609447]
#  [1.1330048 ]
#  [1.0772352 ]
#  [1.2460207 ]
#  [1.1133711 ]
#  [1.437296  ]
#  [1.2540901 ]
#  [1.3489232 ]
#  [0.7713884 ]
#  [0.8574712 ]
#  [0.97747207]
#  [1.0300798 ]
#  [0.24516103]
#  [1.3529196 ]
#  [1.0187846 ]
#  [1.3515584 ]
#  [0.55130893]
#  [1.2647831 ]
#  [0.85604995]
#  [1.3166918 ]
#  [0.98856556]
#  [0.8433807 ]
#  [0.9380532 ]
#  [1.1177807 ]
#  [1.3393285 ]
#  [1.1800973 ]
#  [1.3128278 ]
#  [1.1294856 ]
#  [0.9615227 ]
#  [1.233801  ]
#  [0.7437437 ]
#  [1.1387206 ]
#  [1.0447276 ]
#  [1.1072698 ]
#  [1.4675505 ]
#  [0.47471744]
#  [1.5145974 ]
#  [1.1006297 ]
#  [0.60745305]
#  [1.2346535 ]
#  [1.1671147 ]
#  [1.3124387 ]
#  [0.9321999 ]
#  [1.0326787 ]
#  [1.2446909 ]
#  [1.1300814 ]
#  [0.98597795]
#  [1.144361  ]
#  [1.1635885 ]
#  [0.9275773 ]
#  [0.9747609 ]
#  [1.0084832 ]
#  [1.26241   ]
#  [1.0975646 ]
#  [1.111269  ]
#  [0.9336589 ]
#  [1.3394233 ]
#  [1.031691  ]
#  [1.0658933 ]
#  [0.9600923 ]
#  [0.83612555]
#  [1.1244832 ]
#  [0.9727363 ]
#  [0.3038865 ]
#  [1.1633509 ]
#  [0.75374043]
#  [1.3830409 ]
#  [0.7587887 ]
#  [1.1744993 ]
#  [0.6987338 ]
#  [1.3547572 ]
#  [1.0302482 ]
#  [1.2628007 ]
#  [1.1141815 ]
#  [1.14002   ]
#  [1.0656859 ]
#  [1.3058999 ]
#  [0.9029726 ]
#  [0.9999049 ]
#  [0.5735799 ]
#  [1.5015482 ]
#  [1.1067499 ]
#  [1.3555659 ]
#  [1.2030938 ]
#  [1.3073945 ]
#  [1.1493334 ]
#  [0.6760064 ]
#  [1.2031448 ]
#  [0.89604163]
#  [1.2945939 ]
#  [1.0107175 ]
#  [1.1274486 ]
#  [0.82983613]
#  [0.6212111 ]
#  [0.8131559 ]
#  [0.9240773 ]
#  [1.0779563 ]
#  [0.8143884 ]
#  [1.1953104 ]
#  [1.3731728 ]
#  [1.1765785 ]
#  [1.1899786 ]
#  [0.8776156 ]
#  [1.1567861 ]
#  [0.6754223 ]
#  [1.121447  ]
#  [0.98359   ]
#  [1.2143805 ]
#  [1.0832243 ]
#  [1.0170407 ]
#  [1.1824564 ]
#  [1.1648283 ]
#  [1.1643484 ]
#  [1.242912  ]
#  [1.1263857 ]
#  [0.7412498 ]
#  [0.77545404]
#  [1.2413502 ]
#  [1.0663422 ]
#  [1.0611469 ]
#  [1.0312123 ]
#  [0.99370927]
#  [1.2974966 ]
#  [1.1199307 ]
#  [0.7934018 ]
#  [1.1832286 ]
#  [1.0397149 ]
#  [0.6574046 ]
#  [1.1510092 ]
#  [1.2574596 ]
#  [0.8460454 ]
#  [0.9472824 ]
#  [1.0450711 ]
#  [1.0154662 ]
#  [1.0582182 ]
#  [0.67683434]
#  [1.4517231 ]
#  [1.109994  ]
#  [1.1607728 ]]

# %%
train_acc = model.evaluate(x_train, y_train, verbose=0)[1]

print(train_acc)
# Out:
# 0.9357143044471741

# %%
test_acc = model.evaluate(x_test, y_test, verbose=0)[1]

print(test_acc)
# Out:
# 0.8916666507720947

# %%
pred=model.predict(x_test)
pred = (pred>0.5)
pred
# Out:
# 4/4 [==============================] - 0s 9ms/step
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
from sklearn.metrics import accuracy_score,recall_score,roc_auc_score,confusion_matrix
print("\nAccuracy score: %f" %(accuracy_score(y_test,y_pred) * 100))
print("Recall score : %f" %(recall_score(y_test,y_pred) * 100))
print("ROC score : %f\n" %(roc_auc_score(y_test,y_pred) * 100))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score: 90.000000
# Recall score : 100.000000
# ROC score : 50.000000
#
# [[  0  12]
#  [  0 108]]

# %%
from sklearn.metrics import accuracy_score, recall_score,roc_auc_score, confusion_matrix,classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        12
#         True       0.90      1.00      0.95       108
#
#     accuracy                           0.90       120
#    macro avg       0.45      0.50      0.47       120
# weighted avg       0.81      0.90      0.85       120
# C:\Users\Dhanush\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dhanush\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dhanush\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.save('model.h5')

# %%
import numpy as np
from flask import Flask, request, jsonify,render_template
import pickle
app = Flask(__name__)
from tensorflow.keras.models import load_model

# %%
model = load_model('model.h5')

# %%
@app.route('/')
def home():
    return render_template('Demo2.html')

# %%
@app.route('/y_predict',methods=['POST'])
def y_predict():
    #min max scaling
    min1=[290.0, 92.0, 1.0, 1.0, 1.0, 6.8, 0.0]
    max1=[340.0, 120.0, 5.0, 5,0, 5.0, 9.92, 1.0]
    k= [float(x) for x in request.form.values()]
    p=[]
    for i in range(7):
        l=(k[i]-min1[i])/(max1[i]-min1[i])
        p.append(l)
        prediction = model.predict([p])
        print(prediction)
        output=prediction[0]
        if(output==False):
            return render_template('noChance.html',prediction_text='You Dont have a chance of getting admission')
        else:
            return render_template('chance.html',prediction_text='You have a chance of getting admission')
    if __name__ == "__main__":
        app.run(debug=False)
